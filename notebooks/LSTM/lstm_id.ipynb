# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import to_categorical


df = pd.read_csv("../../data/csv/cleaned_fix.csv")
selected_columns = ["Image", "Scene", "ROI", "FixDur", "FixNr", "Start", "End", "X", "Y", "Participant", "experience"]
df_filtered =  df[selected_columns]
# Out:
# 2025-06-23 17:01:22.683591: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 17:01:24.466822: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750690884.975145 1943949 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750690885.126997 1943949 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750690886.237380 1943949 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750690886.237434 1943949 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750690886.237442 1943949 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750690886.237447 1943949 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-23 17:01:26.330372: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df_filtered.sort_values(by=['Participant', 'FixNr'], inplace=True)
# Out:
# /tmp/ipykernel_1943949/4086940616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by=['Participant', 'FixNr'], inplace=True)

# %%
# --- Encode labels ---
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df_filtered['Participant'])  # 'Label' should be your column with categories
y_onehot = to_categorical(y_encoded)

# --- Normalize features ---
features = df_filtered.drop(columns=['Participant', 'experience'])  # adjust based on your data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# %%
# --- Sliding window function ---
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(len(X) - window_size):
        X_seq.append(X[i:i+window_size])
        y_seq.append(y[i+window_size - 1])  # predict last item in window
    return np.array(X_seq), np.array(y_seq)

# %%
window_size = 5  # adjust as needed
X_seq, y_seq = create_sequences(X_scaled, y_onehot, window_size)

# --- Train/test split ---
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# %%
# --- LSTM Model ---
model = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(32, activation='relu'),
    Dense(36, activation='softmax')  # 4 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# --- Train ---
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.1)
# Out:
# W0000 00:00:1750690899.108230 1943949 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/sam/anaconda3/envs/thesis/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0934 - loss: 3.2926 - val_accuracy: 0.2754 - val_loss: 2.5046
# Epoch 2/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3114 - loss: 2.3576 - val_accuracy: 0.3762 - val_loss: 2.1038
# Epoch 3/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3748 - loss: 2.0728 - val_accuracy: 0.4069 - val_loss: 1.9306
# Epoch 4/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4242 - loss: 1.8981 - val_accuracy: 0.4334 - val_loss: 1.8349
# Epoch 5/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4563 - loss: 1.7788 - val_accuracy: 0.4504 - val_loss: 1.7552
# Epoch 6/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4809 - loss: 1.6883 - val_accuracy: 0.4670 - val_loss: 1.7263
# Epoch 7/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5163 - loss: 1.5933 - val_accuracy: 0.5052 - val_loss: 1.5767
# Epoch 8/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5387 - loss: 1.5083 - val_accuracy: 0.5234 - val_loss: 1.5739
# Epoch 9/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5623 - loss: 1.4494 - val_accuracy: 0.5550 - val_loss: 1.4709
# Epoch 10/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5838 - loss: 1.3817 - val_accuracy: 0.5558 - val_loss: 1.4541
# Epoch 11/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6083 - loss: 1.3007 - val_accuracy: 0.5740 - val_loss: 1.3821
# Epoch 12/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6194 - loss: 1.2510 - val_accuracy: 0.6072 - val_loss: 1.3009
# Epoch 13/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6360 - loss: 1.1923 - val_accuracy: 0.6039 - val_loss: 1.3276
# Epoch 14/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6510 - loss: 1.1453 - val_accuracy: 0.6304 - val_loss: 1.2225
# Epoch 15/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6586 - loss: 1.1069 - val_accuracy: 0.6329 - val_loss: 1.2273
# Epoch 16/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6784 - loss: 1.0589 - val_accuracy: 0.6470 - val_loss: 1.1726
# Epoch 17/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6892 - loss: 1.0179 - val_accuracy: 0.6458 - val_loss: 1.1676
# Epoch 18/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7030 - loss: 0.9747 - val_accuracy: 0.6661 - val_loss: 1.0870
# Epoch 19/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7048 - loss: 0.9543 - val_accuracy: 0.6723 - val_loss: 1.0789
# Epoch 20/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7237 - loss: 0.9072 - val_accuracy: 0.6562 - val_loss: 1.1081
# Epoch 21/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7279 - loss: 0.8822 - val_accuracy: 0.7088 - val_loss: 0.9633
# Epoch 22/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7397 - loss: 0.8476 - val_accuracy: 0.7076 - val_loss: 0.9514
# Epoch 23/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7449 - loss: 0.8234 - val_accuracy: 0.7117 - val_loss: 0.9390
# Epoch 24/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7637 - loss: 0.7782 - val_accuracy: 0.7130 - val_loss: 0.9232
# Epoch 25/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7681 - loss: 0.7610 - val_accuracy: 0.7072 - val_loss: 0.9639
# Epoch 26/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7733 - loss: 0.7360 - val_accuracy: 0.7292 - val_loss: 0.8651
# Epoch 27/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7835 - loss: 0.7106 - val_accuracy: 0.7341 - val_loss: 0.8608
# Epoch 28/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7861 - loss: 0.6939 - val_accuracy: 0.7520 - val_loss: 0.8145
# Epoch 29/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8045 - loss: 0.6514 - val_accuracy: 0.7424 - val_loss: 0.8417
# Epoch 30/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8042 - loss: 0.6546 - val_accuracy: 0.7478 - val_loss: 0.8066
# Epoch 31/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8056 - loss: 0.6410 - val_accuracy: 0.7677 - val_loss: 0.7856
# Epoch 32/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8157 - loss: 0.6115 - val_accuracy: 0.7702 - val_loss: 0.7786
# Epoch 33/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8207 - loss: 0.5841 - val_accuracy: 0.7752 - val_loss: 0.7406
# Epoch 34/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8361 - loss: 0.5472 - val_accuracy: 0.7640 - val_loss: 0.7537
# Epoch 35/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8313 - loss: 0.5576 - val_accuracy: 0.7744 - val_loss: 0.7352
# Epoch 36/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8331 - loss: 0.5525 - val_accuracy: 0.7814 - val_loss: 0.7148
# Epoch 37/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8464 - loss: 0.5152 - val_accuracy: 0.7831 - val_loss: 0.7211
# Epoch 38/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8501 - loss: 0.4990 - val_accuracy: 0.7831 - val_loss: 0.7125
# Epoch 39/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8503 - loss: 0.4917 - val_accuracy: 0.7814 - val_loss: 0.7743
# Epoch 40/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8599 - loss: 0.4684 - val_accuracy: 0.7914 - val_loss: 0.6881
# Epoch 41/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8546 - loss: 0.4845 - val_accuracy: 0.8100 - val_loss: 0.6528
# Epoch 42/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8712 - loss: 0.4347 - val_accuracy: 0.8038 - val_loss: 0.6721
# Epoch 43/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8642 - loss: 0.4440 - val_accuracy: 0.8109 - val_loss: 0.6703
# Epoch 44/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8765 - loss: 0.4169 - val_accuracy: 0.8075 - val_loss: 0.6430
# Epoch 45/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8762 - loss: 0.4095 - val_accuracy: 0.8034 - val_loss: 0.6651
# Epoch 46/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8765 - loss: 0.4132 - val_accuracy: 0.8067 - val_loss: 0.6578
# Epoch 47/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8785 - loss: 0.4007 - val_accuracy: 0.8096 - val_loss: 0.6461
# Epoch 48/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8877 - loss: 0.3863 - val_accuracy: 0.8175 - val_loss: 0.6427
# Epoch 49/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8929 - loss: 0.3600 - val_accuracy: 0.8088 - val_loss: 0.6613
# Epoch 50/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8906 - loss: 0.3731 - val_accuracy: 0.8287 - val_loss: 0.6031
# Epoch 51/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8958 - loss: 0.3552 - val_accuracy: 0.8279 - val_loss: 0.6062
# Epoch 52/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8947 - loss: 0.3546 - val_accuracy: 0.8349 - val_loss: 0.6006
# Epoch 53/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9004 - loss: 0.3403 - val_accuracy: 0.8291 - val_loss: 0.6050
# Epoch 54/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9000 - loss: 0.3378 - val_accuracy: 0.8445 - val_loss: 0.5819
# Epoch 55/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9049 - loss: 0.3226 - val_accuracy: 0.7893 - val_loss: 0.7681
# Epoch 56/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9018 - loss: 0.3294 - val_accuracy: 0.8324 - val_loss: 0.6309
# Epoch 57/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9084 - loss: 0.3125 - val_accuracy: 0.8341 - val_loss: 0.5714
# Epoch 58/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9077 - loss: 0.3114 - val_accuracy: 0.8391 - val_loss: 0.5819
# Epoch 59/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9096 - loss: 0.3107 - val_accuracy: 0.8399 - val_loss: 0.5937
# Epoch 60/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9148 - loss: 0.2957 - val_accuracy: 0.8424 - val_loss: 0.5769
# Epoch 61/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9133 - loss: 0.2962 - val_accuracy: 0.8362 - val_loss: 0.5915
# Epoch 62/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9149 - loss: 0.2890 - val_accuracy: 0.8324 - val_loss: 0.5808
# Epoch 63/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9143 - loss: 0.2881 - val_accuracy: 0.8470 - val_loss: 0.5563
# Epoch 64/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9147 - loss: 0.2894 - val_accuracy: 0.8374 - val_loss: 0.5804
# Epoch 65/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9221 - loss: 0.2701 - val_accuracy: 0.8416 - val_loss: 0.5880
# Epoch 66/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9179 - loss: 0.2753 - val_accuracy: 0.8295 - val_loss: 0.6011
# Epoch 67/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9218 - loss: 0.2686 - val_accuracy: 0.8146 - val_loss: 0.7009
# Epoch 68/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9197 - loss: 0.2771 - val_accuracy: 0.8507 - val_loss: 0.5604
# Epoch 69/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9253 - loss: 0.2529 - val_accuracy: 0.8544 - val_loss: 0.5198
# Epoch 70/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9241 - loss: 0.2561 - val_accuracy: 0.8528 - val_loss: 0.5630
# Epoch 71/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9237 - loss: 0.2535 - val_accuracy: 0.8523 - val_loss: 0.5516
# Epoch 72/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9310 - loss: 0.2388 - val_accuracy: 0.8586 - val_loss: 0.5459
# Epoch 73/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9350 - loss: 0.2283 - val_accuracy: 0.8374 - val_loss: 0.6052
# Epoch 74/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9278 - loss: 0.2404 - val_accuracy: 0.8465 - val_loss: 0.5423
# Epoch 75/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9313 - loss: 0.2345 - val_accuracy: 0.8515 - val_loss: 0.5657
# Epoch 76/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9284 - loss: 0.2401 - val_accuracy: 0.8635 - val_loss: 0.5277
# Epoch 77/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9376 - loss: 0.2150 - val_accuracy: 0.8698 - val_loss: 0.5058
# Epoch 78/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9421 - loss: 0.2012 - val_accuracy: 0.8461 - val_loss: 0.5961
# Epoch 79/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9351 - loss: 0.2149 - val_accuracy: 0.8644 - val_loss: 0.5365
# Epoch 80/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9275 - loss: 0.2366 - val_accuracy: 0.8627 - val_loss: 0.5277
# Epoch 81/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9392 - loss: 0.2057 - val_accuracy: 0.8552 - val_loss: 0.5553
# Epoch 82/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9416 - loss: 0.2045 - val_accuracy: 0.8523 - val_loss: 0.5618
# Epoch 83/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9406 - loss: 0.2018 - val_accuracy: 0.8631 - val_loss: 0.5603
# Epoch 84/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9373 - loss: 0.2087 - val_accuracy: 0.8714 - val_loss: 0.5299
# Epoch 85/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1979 - val_accuracy: 0.8693 - val_loss: 0.5039
# Epoch 86/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9476 - loss: 0.1853 - val_accuracy: 0.8710 - val_loss: 0.4999
# Epoch 87/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.
200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9832 - loss: 0.0598 - val_accuracy: 0.8785 - val_loss: 0.6598
# Epoch 190/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9712 - loss: 0.0952 - val_accuracy: 0.8801 - val_loss: 0.5994
# Epoch 191/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9726 - loss: 0.0890 - val_accuracy: 0.8747 - val_loss: 0.6383
# Epoch 192/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9770 - loss: 0.0748 - val_accuracy: 0.8814 - val_loss: 0.6388
# Epoch 193/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9797 - loss: 0.0670 - val_accuracy: 0.8818 - val_loss: 0.6195
# Epoch 194/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9783 - loss: 0.0718 - val_accuracy: 0.8822 - val_loss: 0.6380
# Epoch 195/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9742 - loss: 0.0866 - val_accuracy: 0.8772 - val_loss: 0.6382
# Epoch 196/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9737 - loss: 0.0807 - val_accuracy: 0.8942 - val_loss: 0.5400
# Epoch 197/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9834 - loss: 0.0578 - val_accuracy: 0.8747 - val_loss: 0.6419
# Epoch 198/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9785 - loss: 0.0736 - val_accuracy: 0.8781 - val_loss: 0.5836
# Epoch 199/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9726 - loss: 0.0885 - val_accuracy: 0.8818 - val_loss: 0.6139
# Epoch 200/200
# 678/678 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9793 - loss: 0.0731 - val_accuracy: 0.8781 - val_loss: 0.6578

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# --- Evaluate ---
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.8657 - loss: 0.7561
# Test Accuracy: 0.86

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# --- Predict on test set ---
y_pred_probs = model.predict(X_test)                     # Get prediction probabilities
y_pred = np.argmax(y_pred_probs, axis=1)                 # Convert to class indices
y_true = np.argmax(y_test, axis=1)                       # Convert one-hot to class indices

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)

# Plot without numbers and larger figure
fig, ax = plt.subplots(figsize=(30, 10))  # Increase size (adjust as needed)
disp.plot(cmap=plt.cm.Blues, ax=ax, include_values=False)  # values_format='' removes the numbers
plt.title('Confusion Matrix')
ax.tick_params("x", rotation=45)
plt.show()
# Out:
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       317
#            1       0.81      0.69      0.74        67
#            2       0.85      0.82      0.84       182
#            3       0.81      0.87      0.84       139
#            4       0.88      0.76      0.82       106
#            5       0.77      0.81      0.79       108
#            6       0.80      0.77      0.79       158
#            7       0.90      0.90      0.90       178
#            8       1.00      0.98      0.99        48
#            9       0.86      0.91      0.88       215
#           10       0.95      0.87      0.90       319
#           11       0.91      0.88      0.90       121
#           12       0.82      0.89      0.85       214
#           13       0.92      0.96      0.94       161
#           14       0.91      0.95      0.93       303
#           15       0.81      0.76      0.78       124
#           16       0.87      0.78      0.82       187
#           17       0.76      0.83      0.79       103
#           18       0.90      0.86      0.88       266
#           19       0.84      0.88      0.86       162
#           20       0.71      0.78      0.74        96
#           21       0.81      0.84      0.82       158
#           22       0.84      0.93      0.88       241
#           23       0.82      0.78      0.80        96
#           24       0.94      0.82      0.88       136
#           25       0.93      0.81      0.86       178
#           26       0.75      0.85      0.80       183
#           27       0.76      0.78      0.77       122
#           28       0.93      0.89      0.91       206
#           29       0.96      0.92      0.94       245
#           30       0.82      0.87      0.84       121
#           31       0.84      0.89      0.86       151
#           32       0.84      0.88      0.86       172
#           33       0.87      0.82      0.84       166
#           34       0.88      0.94      0.91       178
#           35       0.67      0.63      0.65        99
#
#     accuracy                           0.86      6026
#    macro avg       0.85      0.85      0.85      6026
# weighted avg       0.87      0.86      0.86      6026
